# %%
import pandas as pd

# reading jsonl file to dataframe
df_jsonl = pd.read_json('./data/Jobs_NYC_Postings.jsonl', orient='records', lines=True)
pd.get_option("display.max_columns")
pd.get_option("display.max_colwidth")
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 100)

df_jsonl[0:1]
# Out:
#    Job ID                    Agency Posting Type  # Of Positions  \
# 0  606346  DEPARTMENT FOR THE AGING     External               1
#
#                 Business Title      Civil Service Title Title Classification  \
# 0  Business Operations Analyst  ASSOCIATE STAFF ANALYST        Competitive-1
#
#   Title Code No Level  \
# 0         12627    00
#
#                                                                                  Job Category  \
# 0  Administration & Human Resources Technology, Data & Innovation Policy, Research & Analysis
#
#   Full-Time/Part-Time indicator               Career Level  Salary Range From  \
# 0                             F  Experienced (non-manager)            70611.0
#
#    Salary Range To Salary Frequency          Work Location Division/Work Unit  \
# 0          81203.0           Annual  2 Lafayette St., N.Y.    Human Resources
#
#                                                                                        Job Description  \
# ...

# %%
print(df_jsonl.shape)
df_jsonl.loc[0:, ["Salary Range From", "Salary Range To"]]
# Out:
# (6186, 30)
#       Salary Range From  Salary Range To
# 0               70611.0          81203.0
# 1               72038.0         192152.0
# 2               65604.0          83399.0
# 3               60793.0          69912.0
# 4               39763.0          64420.0
# ...                 ...              ...
# 6181            48612.0          76735.0
# 6182            92301.0         106146.0
# 6183            82506.0          94882.0
# 6184            70611.0          83109.0
# 6185            62370.0          93587.0
#
# [6186 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from pylab import rcParams
import numpy as np

# %%
rcParams['figure.figsize'] = 15, 5 # Graph Size (width, height)
plt.tight_layout() # Function to prevent graphs from overlapping each other

plt.xlabel("salary range from", fontsize=12) # x-axis label
plt.ylabel("num of JD", fontsize=12) # y-axis label
plt.title("salary_histogram", fontsize=10)

plt.xlim(0, 250000) # x-axis range
plt.ylim(0, 500) # y-axis range

df_jsonl['Salary Range From'].hist(bins=1000, range=(0, 250000), ec='blue') 

plt.show() # Graph Display

# %%
plt.xlabel("salary range to", fontsize=12) # x-axis label
plt.ylabel("num of JD", fontsize=12) # y-axis label
plt.title("salary_histogram", fontsize=10)

plt.xlim(0, 250000) # x-axis range
plt.ylim(0, 500) # y-axis range
df_jsonl['Salary Range To'].hist(bins=1000, range=(0, 250000), ec='red') 

plt.show() # Graph Display

# %%
plt.xlabel("salary range from / to", fontsize=12) # x-axis label
plt.ylabel("num of JD", fontsize=12) # y-axis label
plt.title("salary_histogram", fontsize=10)

plt.xlim(0, 250000) # x-axis range
plt.ylim(0, 500) # y-axis range

bins = np.linspace(0, 250000, 100)

plt.hist([df_jsonl['Salary Range From'], df_jsonl['Salary Range To']], bins, label=["salary range from", "salary range to"])
plt.legend(loc="upper right")
plt.show() # Graph Display
